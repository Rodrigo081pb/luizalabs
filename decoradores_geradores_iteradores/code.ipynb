# %%
def mensagem(nome):
    print("mensagem executando")
    return f'Oi {nome}'

def mensagem_long(nome):
    print("MENSAGEM LONGA")
    return f"Olá tudo bem ? {nome}"

def executar(funcao, nome):
    print("Executando")
    return funcao('Rodrigo')

print(executar(mensagem, "Olivio"))
# print(executar(mensagem_long, "Olivio"))
# Out:
# Executando
# mensagem executando
# Oi Rodrigo

# %%
# Função interna

def principal():
    print("Executando a função principal")

    def funcao_intern():
        print("Executando a função interna")

    funcao_intern()

principal()
# Out:
# Executando a função principal
# Executando a função interna
